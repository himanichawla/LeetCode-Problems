# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class Linked_list:
    def __init__(self):
        self.head = None
    def print_list(self):
        node = self.head
        while(node!= None):
            print(node.data)
            node = node.next
    def insert_at_beg(self,x):
        new_node = Node(x)
        new_node.next = self.head
        self.head = new_node
    def insert_at_end(self,x):
        new_node = Node(x)
        last_node = self.head
        while(last_node.next!=None):
            last_node = last_node.next
        last_node.next = new_node
    def insert_at_pos(self,x,data):
        new_node = Node(x)
        temp = self.head
        while(temp.data!=data):
            temp = temp.next
        new_temp = temp.next
        temp.next = new_node
        new_node.next = new_temp
    def del_node(self,d):
        node = self.head
        print("head: ", node.data)
        if(node.data ==d):
            print("Deleting head node")
            temp = node.next
            self.head = node.next
        else:
            while(node.data!=d):
                previous = node
                node = node.next
                
            previous.next = node.next
    def reverse_list(self):
        prev = None
        current = self.head
        Next = next
        while(current is not None):
            Next = current.next
            current.next = prev
            prev = current
            current = Next
        self.head = prev
    
    def get_nth(self,n):
        current = self.head
        count = 0
        while(current):
            if(count==n):
                return current.data
            else:
                count+=1
                current = current.next
    
    def check_pallindrome(self):
        if not self.head or not self.head.next:
            return True
        slow = fast = curr = self.head
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next
        stack= [slow.data]
        while slow.next:
            slow = slow.next
            stack.append(slow.data)
        while stack:
            if stack.pop()!=curr.data:
                return False
            curr = curr.next
        return True
    def remove_duplicates(self):
        current = self.head
        Next = None
        while(current.next):
#             Next = current.next
            if(current.next.data == current.data):
                current.next = current.next.next
            else:
                current = current.next
    def remove_duplicates_unsorted(self):
       
        previous = self.head
        current = previous.next
        s=set([previous.data])
        while(current):
            if(current.data in s):
                previous.next = current.next
                current =current.next
            else:
                s.add(current.data)
                previous = current
                current = current.next

# %%
if __name__=='__main__':
    llist = Linked_list()
    llist.head = Node(1)
#     llist.head.next = Node(2)
#     llist.head.next.next = Node(3)
#     llist.print_list()
    llist.insert_at_beg(2)
    llist.insert_at_beg(2)
    llist.insert_at_beg(3)
    llist.insert_at_beg(6)
    llist.insert_at_beg(7)
    llist.insert_at_beg(7)
    llist.insert_at_beg(4)
#     llist.insert_at_beg(1)
#     llist.insert_at_end(1)
#     llist.insert_at_pos(2,2)
#     llist.print_list()
#     llist.del_node(5)
#     print("After Deletion")
    llist.print_list()
#     print ("length of linked List")
#     return_length(llist.head)
#     print(llist.get_nth(4))
#     print(llist.check_pallindrome())
#     llist.remove_duplicates()
#     print("after removing duplicates:")
#     llist.print_list()
    llist.remove_duplicates_unsorted()
    print("after removing from unsorted list:")
    llist.print_list()
# Out:
# 4
# 7
# 7
# 6
# 3
# 2
# 2
# 1
# after removing from unsorted list:
# 4
# 7
# 6
# 3
# 2
# 1

# %%
# Length of linked list
def return_length(head):
    current = head
    length =0
    while(current is not None):
        current = current.next
        length +=1
    print("length:" , length)
    return length
def intersection(head1,head2):
    count1,count2 =0,0
    current1,current2 = head1,head2
    while(head1):
        head1 = head1.next
        count1+=1
    while(head2):
        head2= head2.next
        count2+=1
    if(count1 > count2):
        diff = count1 -count2
        while(diff!=0):
            current1 = current1.next
            diff-=1
    if(count1 < count2):
        diff1 = count2 - count1
        while(diff1!=0):
            current2 = current2.next
            diff1-=1
    while(current1 and current2):
        if(current1.data == current2.data):
#             print(current1.data)
            return current1.data
        current1 = current1.next
        current2 = current2.next
        
def detect_loop(head):
    slow_ptr, fast_ptr = head, head
    while(fast_ptr and slow_ptr and fast_ptr.next):
        slow_ptr = slow_ptr.next
        fast_ptr = fast_ptr.next.next
        if(slow_ptr == fast_ptr):
            return True
def loop_start(head):
    if head = None or head.next =None:
        return None
    slow_ptr, fast_ptr = head,head
    while(fast_ptr and slow_ptr and fast_ptr and slow_ptr!=fast_ptr):
        slow_ptr = slow_ptr.next
        fast_ptr = fast_ptr.next.next
    if fast_ptr==None or fast_ptr.next==None:
        return None
    slow_ptr = head
    print("fast", fast_ptr.data)
    while (slow_ptr!=fast_ptr):
        slow_ptr = slow_ptr.next
        fast_ptr = fast_ptr.next
    return slow_ptr
    
            
    
def print_list2(head):
    while(head is not None):
        print(head.data)
        head = head.next

if __name__=='__main__':
    llist = Linked_list()
    llist1 = Linked_list()
    llist.head = Node(6)
#     llist.head.next = Node(2)
#     llist.head.next.next = Node(3)
#     llist.print_list()
    
    llist.insert_at_beg(5)
    llist.insert_at_beg(4)
    llist.insert_at_beg(3)
    llist.insert_at_beg(2)
    llist.insert_at_beg(1)
    llist.print_list()
    llist.head.next.next.next.next = llist.head
    print (detect_loop(llist.head))
#     llist1.head = Node(6)
#     llist1.insert_at_beg(5)
#     llist1.insert_at_beg(4)
#     llist1.insert_at_beg(8)
#     llist1.insert_at_beg(7)
#     print("List1:")
#     llist.print_list()
#     print("List2:")
#     llist1.print_list()
#     print("intersection:")
#     print(intersection(llist.head,llist1.head))
# Out:
#   File "<ipython-input-165-d33bc82d6424>", line 44
#     if head = None or head.next =None:
#             ^
# SyntaxError: invalid syntax

# %%
class Node2:
    def __init__(self,d):
        self.data = d
        self.previous= None
        self.next = None
class double_linked_list:
    def __init__(self):
        self.head = None
    def insert_at_beg(self,x):
        new_node = Node2(x)
        current = self.head
        new_node.previous = None
        new_node.next = current
        self.head = new_node
    def insert_at_end(self,x):
        new_node = Node2(x)
        last_node = self.head
        while(last_node.next is not None):
            last_node = last_node.next
        last_node.next = new_node
        new_node.prev = last_node
        new_node.next = None
    def insert_at_middle(self,x,d):
        new_node = Node2(x)
        temp = self.head
        while(temp.data!=d):
            temp = temp.next
        new_temp = temp.next
        temp.next = new_node
        new_node.previous = temp 
        new_node.next = new_temp
        new_temp.previous = new_node
    def print_list(self):
        node = self.head
        while(node!= None):
            print(node.data)
            node = node.next

# %%
if __name__ == '__main__':
    llist1= double_linked_list()
    llist1.head = Node(1)
    llist1.head.next = Node(2)
    llist1.head.next.next = Node(3)
    llist1.insert_at_beg(4)
    llist1.insert_at_end(5)
    llist1.insert_at_middle(6,3)
    llist1.print_list()
# Out:
# 4
# 1
# 2
# 3
# 6
# 5

# %%
#     llist.reverse_list()
#     print("reversing the ll")
#     llist.print_list()
# Out:
# 3
# 2
# 1
# 1
# 2
# 3
# length of linked List
# length: 6
# 2
# True

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
class LinkedList:
    def __init__(self):
        self.head = None
    def swapnodes(self):
        current = self.head
        while(current != None and current.next !=None):
            temp = current
            next1 = current.next
            next1.next = current
